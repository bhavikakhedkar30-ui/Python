# %%
print("sorrie")
# Out:
# sorrie

# %%
x=5
y=7
z=5
print(id(x),id(y),id(z))
# Out:
# 140706175677480 140706175677544 140706175677480

# %%
lenght = int(input("Enter lenght: "))
breadth = int(input("Enter breadth: "))
area = lenght*breadth
print("Area of the rectanle is:=",area)
# Out:
# 4

# %%
Celsius = int(input("Enter the Celsius Temperature: "))
Convert = 9/5*(Celsius) + 32 
print("The Fahrenheit Temp is :  ",Convert)
# Out:
# The Fahrenheit Temp is :   50.0
